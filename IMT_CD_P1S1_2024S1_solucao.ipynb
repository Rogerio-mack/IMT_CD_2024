# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/IMT_CD_2024/blob/main/IMT_CD_P1S1_2024S1_solucao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <head>
#   <meta name="author" content="Rogério de Oliveira">
#   <meta institution="author" content="ITM">
# </head>
#
# <img src="https://maua.br/images/selo-60-anos-maua.svg" width=300, align="right">
# <!-- <h1 align=left><font size = 6, style="color:rgb(200,0,0)"> optional title </font></h1> -->

# %% [markdown]
# # **P1S1 2024S1 ECM514 LAB - Ciência de Dados**
#
# Nesta avaliação você terá a oportunidade de empregar o que aprendeu atá aqui para fazer diversas análises interessantes sobre dados como **posts de notícias (CNN), preços do Airbnb, emissões (CO2) no mundo e renda e desigualdade no Brasil** (os cases variam para cada prova).
#
# Antes de iniciar cada case, explore e entenda os dados empregados.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

path = 'https://github.com/Rogerio-mack/IMT_CD_2024/raw/main/data/'

# %% [markdown]
# # **Case 1**: CNN news
#
# Neste case analise comentários de notícias postados pelo canal CNN.

# %%
df = pd.read_csv(path + 'Cleaned_cnn_comments.csv')
df.head()
# Out:
#                                         comment_text likes  comment_time
# 0  Just like US did not abandon Vietnam, Iraq, Af...    73        7200.0
# 1  Anybody else getting tired of these people spe...   193        7200.0
# 2  "If two fish are fighting in a river an Englis...    45        7200.0
# 3  "Not abandon" is not equal to "Defend/no fly-z...     7        7200.0
# 4  It's time we pray that our world leaders get a...    52        7200.0

# %% [markdown]
# # Q11. Temas mais frenquentes nos posts
#
# **Considere os posts com as palavras `['Biden','Trump','Ukraine','Russia','US']`. Quais aparecem com maior frequência nos posts da CNN?**
#
# <br>
#
# Dicas:
# 1. Considere as palavras como estão. Não é necessário considerar variações das palavras (como maíscula/minúscula).
# 2. No caso de mais de um termo estar presente, considere somente o 1o termo que surgir na ordem que eles se apresentam acima.

# %%
def word_exist(x):
  for word in ['Biden','Trump','Ukraine','Russia','US']:
    if x.count(word) > 0:
      return word
  return None

df['word'] = df.comment_text.apply(lambda x: word_exist(x))

# df[ ~df['word'].isnull() ]

df.groupby('word').word.count().sort_values(ascending=False)
# Out:
# word
# Trump      1162
# Ukraine     881
# Russia      575
# US          418
# Biden       289
# Name: word, dtype: int64

# %% [markdown]
# # Q12. Mais comentários, mais likes?
#
# **Considere os posts com as palavras `['Biden','Trump','Ukraine','Russia','US']`. Quais apresentam maior quantidade de likes?**
#
# <br>
#
# Dicas:
# 1. Considere as palavras como estão. Não é necessário considerar variações das palavras (como maíscula/minúscula).
# 2. No caso de mais de um termo estar presente, considere somente o 1o termo que surgir na ordem que eles se apresentam acima.
# 3. **Atenção, inspecione os valores de `likes`** e faça as transformações necessárias. `apply()` e `replace()` ('K') podem ser úteis aqui.

# %%
def change_stringK2value(s):

  if s.find('K') > 0:
    s = s.replace('K','')
    value = float(s) * 1000
  else:
    value = float(s)

  return value

df['likes_numeric'] = df.likes.apply(lambda s: change_stringK2value(s))

df.groupby('word').likes_numeric.sum().sort_values(ascending=False)
# Out:
# word
# Trump      46559.0
# Ukraine    17627.0
# Russia     13408.0
# US         10080.0
# Biden       2583.0
# Name: likes_numeric, dtype: float64

# %% [markdown]
# # **Case 2**: Airbnb
#
# Neste case analise dados sobre imóveis alugados pela plataforma Airbnb em NYC no ano de 2019.

# %%
df = pd.read_csv(path + 'AB_NYC_2019.csv')
df.head()
# Out:
#        id                                            name  host_id  \
# 0   20913              Charming 1 bed GR8 WBurg LOCATION!    79402
# 1   25235               Large 2 Bedroom Great for Groups!    87773
# 2   76761  Eveland the Place to Stay & Enjoy a 5-⭐️ 2bdrm   118971
# 3  135465             Garden apartment close to Manhattan   663879
# 4  169002                Modern Space in Charming Pre-war   805344
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0   Christiana            Brooklyn        Williamsburg  40.70984  -73.95775
# 1       Shelly            Brooklyn  Bedford-Stuyvesant  40.68373  -73.92377
# 2       Evelyn            Brooklyn         South Slope  40.66552  -73.99019
# 3  Christopher            Brooklyn         Fort Greene  40.68626  -73.97598
# 4         Alec           Manhattan              Harlem  40.82411  -73.94934
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    100               5                168  2018-07-22
# 1  Entire home/apt    125              90                162  2019-06-28
# 2  Entire home/apt    169               2                398  2019-06-28
# 3  Entire home/apt    170               3                 86  2019-06-20
# 4     Private room     65               2                 41  2019-06-16
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               1.57                               1                 0
# 1               1.46                               2               137
# 2               3.97                               3               182
# 3               0.91                               2               286
# 4               0.43                               2                59

# %% [markdown]
# # Q21. Proprietários com mais imóveis na plataforma
#
# **Existem proprietários ("hosts") alugando mais de um imóvel na plataforma? Se sim, qual é o proprietário com mais imóveis na base da plataforma e quantos ele possui na plataforma?**
#
# <br>
#
# Dicas:
# 1. Atenção, pode haver nomes *homônimos*.

# %%
df.groupby(['host_name','host_id']).id.count().sort_values(ascending=False).head()
# Out:
# host_name     host_id
# Sonder (NYC)  219517861    7
# Stanley       120762452    4
# Kara          30283594     4
# Hiroki        19303369     4
# Adeyemi       86327101     2
# Name: id, dtype: int64

# %% [markdown]
# Veja aqui se você não considerou a observação de *homônimos*.

# %%
df.groupby(['host_name']).id.count().sort_values(ascending=False).head()
# Out:
# host_name
# Mark            7
# Sonder (NYC)    7
# David           6
# Andrew          6
# Mike            5
# Name: id, dtype: int64

# %%
df[ df.host_name == 'Mark' ][['host_name','host_id']]
# Out:
#     host_name    host_id
# 305      Mark   92322271
# 396      Mark   14140453
# 415      Mark  145011016
# 576      Mark  124743046
# 614      Mark  215229943
# 696      Mark  109448921
# 735      Mark   52577963

# %% [markdown]
# # Q22. O preço dos imóveis entre anunciantes de vários imóveis (locatários profissionais) e anunciantes com um único imóvel
#
# **Considere o preço médio dos imóveis. Existe diferença do preço médio dos imóveis dos anunciantes com mais de um imóvel e dos anunciantes com um único imóvel na plataforma?**

# %%
df_count = df.groupby('host_id')[['id']].count()
df_count = df_count[ df_count.id > 1 ]

print( f'Preço médio para anunciantes com mais de um imóvel: {df[ df.host_id.isin( df_count.index ) ].price.mean():.2f}')
print( f'Preço médio para anunciantes com um único imóvel: {df[ ~df.host_id.isin( df_count.index ) ].price.mean():.2f}')
print( f'Diferença de preços: {df[ df.host_id.isin( df_count.index ) ].price.mean() - df[ ~df.host_id.isin( df_count.index ) ].price.mean():.2f}')
# Out:
# Preço médio para anunciantes com mais de um imóvel: 218.16
# Preço médio para anunciantes com um único imóvel: 150.35
# Diferença de preços: 67.81

# %% [markdown]
# # Q23. Preços em Manhattan
#
# **Qual a vizinhança (`neighbourhood_group`) de Manhattan com a maior média de preços de aluguel, e qual é esse valor?**
#
# <br>
# Dicas:
# 1. Pode ser útil empregar `sort_values()` ou `nlargest()`.

# %%
df[ df.neighbourhood_group == 'Manhattan' ].groupby('neighbourhood').price.mean().sort_values(ascending=False).head(3)
# Out:
# neighbourhood
# West Village         440.529412
# Flatiron District    375.000000
# Midtown              346.033333
# Name: price, dtype: float64

# %% [markdown]
# # Q24.  Manhattan $\times$ Brooklyn
#
# **Qual o percentual de imóveis de Manhattan e do Brooklyn com preços estatisticamente discrepantes (*outliers*) com relação ao preço geral (toda a base) dos imóveis?**
#
# <br>
#
# Nota:
# 1. Lembrando, *outliers* são dados fora do intervalo
#
# $$[Q1 - 1.5 \times IQR, Q3 + 1.5 \times IQR]$$
#
# > onde $IQR$ é a distância interquartil.

# %%
q1, q3 = df.price.quantile([0.25,0.75])
iqr = q3 - q1

perc_Manhattan = df[ (df.neighbourhood_group == 'Manhattan') & (df.price >= q3 + 1.5 * iqr) ].id.count() / len(df[ (df.neighbourhood_group == 'Manhattan') ])
perc_Brooklyn  = df[ (df.neighbourhood_group == 'Brooklyn') & (df.price >= q3 + 1.5 * iqr) ].id.count() / len(df[ (df.neighbourhood_group == 'Brooklyn') ])

print( f'Percentuais de outliers de preços, Manhattan: {perc_Manhattan:.3f} e Brooklyn: {perc_Brooklyn:.3f}')
# Out:
# Percentuais de outliers de preços, Manhattan: 0.101 e Brooklyn: 0.039

# %% [markdown]
# # Q25. Maiores variações de preço
#
# **Há alguma vizinhaça (`neighbourhood_group`) que o desvio padrão dos preços é maior que os próprios preços!?!? Se sim, quais são essas vizinhaças?**

# %%
df_mean_std = df.groupby('neighbourhood_group').price.agg(['mean','std'])
df_mean_std['std > mean'] = df_mean_std['std'] > df_mean_std['mean']
df_mean_std
# Out:
#                            mean         std  std > mean
# neighbourhood_group
# Bronx                 71.500000   32.246583       False
# Brooklyn             128.087879  135.909080        True
# Manhattan            196.157609  234.131794        True
# Queens                92.227848   72.164511       False
# Staten Island         89.428571   40.236207       False

# %% [markdown]
# # Q26. Reviews $\times$ Preços, influenciam de que forma?
#
# **Considere os imóveis com as 100 maiores quantidades de "revisões" (`number_of_reviews`) e os imóveis com as 100 menores quantidades de "revisões".  Existe diferença do preço médio dos imóveis entre esses dois grupos? Qual é essa diferença?**
#
# <br>
#
# Dica:
# 1. Atenção: Os imóveis com as 100 maiores (menores) quantidades de reviews não pode ser obtida direta e somente com `nlargest(100)` (`nsmallest(100)`) (por que???). Mesmo assim esses comandos podem ser úteis aqui.
#
# > $[1, 2, 3, 3, 3, 4, 5, 6]$, por exemplo tem `nsmallest(3)` = $[1, 2, 3]$, mas $[1, 2, 3, 3, 3]$ ocorrências com os 3 menores valores!

# %%
more_reviews = df.nlargest(100,'number_of_reviews').number_of_reviews.min()
less_reviews = df.nsmallest(100,'number_of_reviews').number_of_reviews.max()

mean_more_reviews = df[ (df.number_of_reviews >= more_reviews) ].price.mean()
mean_less_reviews = df[ (df.number_of_reviews <= less_reviews) ].price.mean()

print( f'Preço médio de imóveis com mais reviews: {mean_more_reviews:.2f}')
print( f'Preço médio de imóveis com menos reviews: {mean_less_reviews:.2f}')
print( f'Diferença de preços: {mean_more_reviews - mean_less_reviews:.2f}')
# Out:
# Preço médio de imóveis com mais reviews: 124.62
# Preço médio de imóveis com menos reviews: 188.89
# Diferença de preços: -64.27

# %% [markdown]
# Veja a diferença de empregar diretamente `nlargest(100)` e `nsmallest(100)`

# %%
mean_more_reviews = df.nlargest(100,'number_of_reviews').price.mean()
mean_less_reviews = df.nsmallest(100,'number_of_reviews').price.mean()

print( f'Preço médio de imóveis com mais reviews: {mean_more_reviews:.2f}')
print( f'Preço médio de imóveis com menos reviews: {mean_less_reviews:.2f}')
print( f'Diferença de preços: {mean_more_reviews - mean_less_reviews:.2f}')
# Out:
# Preço médio de imóveis com mais reviews: 124.62
# Preço médio de imóveis com menos reviews: 162.38
# Diferença de preços: -37.76

# %% [markdown]
# # **Case 3**: Gapminder
#
# Neste case você analise dados sobre as emissões de CO2 no mundo.

# %% [markdown]
# <img src="https://www.gapminder.org/wp-content/themes/gapminder2/images/gapminder-logo.svg" width=300>

# %%
df = pd.read_csv(path + 'gapminder_co2_emissions_tonnes_per_person.csv')
df.head()
# Out:
#        country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0  Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1      Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2      Algeria   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3      Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4       Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#     2009  2010   2011   2012  2013   2014   2015   2016   2017   2018
# 0  0.238  0.29  0.406  0.345  0.28  0.253  0.262  0.245  0.247  0.254
# 1  1.470  1.56  1.790  1.690  1.69  1.900  1.600    NaN  1.610  1.590
# 2  3.400  3.28  3.270  3.430  3.48  3.680  3.800  3.640  3.560  3.690
# 3  6.120  6.12  5.870  5.920  5.90  5.830  5.970  6.070  6.270  6.120
# 4  1.230  1.24  1.250    NaN  1.28  1.640  1.220  1.180  1.140  1.120
#
# [5 rows x 220 columns]

# %% [markdown]
# # Q31. Países controlam emissões há mais de 200 anos?
#
# **Que países medem/reportam emissões desde 1800? Qual o total de emissões desses países em 1800?**
#
# <br>
#
# Dicas:
# 1. `isnull()` pode ser útil aqui.

# %%
df[ ~df['1800'].isnull() ]
# Out:
#             country     1800     1801     1802     1803     1804     1805  \
# 30           Canada  0.00733  0.00716  0.00698  0.00681  0.00665  0.00649
# 64          Germany  0.04420  0.02930  0.02980  0.02830  0.05250  0.05340
# 137          Poland  0.04520  0.04890  0.04940  0.05020  0.04950  0.06130
# 182  United Kingdom  2.48000  2.46000  2.45000  2.72000  2.70000  2.78000
# 183   United States  0.04220  0.04380  0.04650  0.04680  0.05160  0.05170
#
#         1806     1807     1808  ...   2009   2010   2011   2012   2013   2014  \
# 30   0.00633  0.00618  0.00603  ...  16.10  16.30  16.40  16.30  16.40  16.20
# 64   0.04730  0.13300  0.04380  ...   9.76  10.30  10.00  10.10  10.30   9.74
# 137  0.05540  0.03990  0.05260  ...   8.23   8.71   8.70   8.52   8.43   8.11
# 182  2.90000  2.87000  2.84000  ...   7.87   8.07   7.34   7.56   7.36   6.71
# 183  0.04970  0.05520  0.05630  ...  17.90  18.50  17.90  17.10  17.50  17.50
#
#       2015   2016   2017   2018
# 30   16.00  15.50  15.60  15.30
# 64    9.74   9.76   9.66   9.14
# 137   8.22   8.51   8.88   9.07
# 182   6.42   6.04   5.81   5.65
# 183  16.90  16.40  16.20  16.60
#
# [5 rows x 220 columns]

# %%
print( f"Total de emissões reportadas em 1800: {df[ ~df['1800'].isnull() ]['1800'].sum():.3f}")
# Out:
# Total de emissões reportadas em 1800: 2.619

# %% [markdown]
# # Q32. Emissões nos últimos 10 anos
#
# Note que há vários países que passaram a medir/reportar as emissões muito após o ano de 1800. Você não precisa se preocupar com a ausência desses valores. Mas observando valores dos últimos 10 anos você encontra alguns *gaps*, como no caso da Albania no ano de 2016 que não reportou a quantidade de emissões (ou Angola, no ano de 2012).
#
# Preencha esses valores ausentes para os últimos 10 anos com o valor do ano anterior. Crie então uma coluna `mean10years` com os valores médios de emissões dos últimos 10 anos de cada país. Em seguida responda:
#
# **Qual o percentual de países geraram mais emissões no ano de 2018 que a média de seus últimos 10 anos? (o ano de 2018 incluído)**
#
# <br>
#
# Dicas:
# 1. Para preencher os valores você pode querer empregar `fillna()`. Verifique as opções do comando.

# %%
df.iloc[:,-10::].fillna(method='ffill',axis=1).head()
# Out:
#     2009  2010   2011   2012  2013   2014   2015   2016   2017   2018
# 0  0.238  0.29  0.406  0.345  0.28  0.253  0.262  0.245  0.247  0.254
# 1  1.470  1.56  1.790  1.690  1.69  1.900  1.600  1.600  1.610  1.590
# 2  3.400  3.28  3.270  3.430  3.48  3.680  3.800  3.640  3.560  3.690
# 3  6.120  6.12  5.870  5.920  5.90  5.830  5.970  6.070  6.270  6.120
# 4  1.230  1.24  1.250  1.250  1.28  1.640  1.220  1.180  1.140  1.120

# %%
df['mean10years'] = df.iloc[:,-10::].fillna(method='ffill',axis=1).mean(axis=1)

print( f"Percentual de países geraram mais emissões no ano de 2018 que a média de seus últimos 10 anos: {len( df[ df['2018'] > df['mean10years'] ] ) / len(df) :.3f}")
# Out:
# Percentual de países geraram mais emissões no ano de 2018 que a média de seus últimos 10 anos: 0.594

# %% [markdown]
# # Q33. Emissões e a China
#
# **Qual a posição da China na lista dos países mais emissores considerando a  média dos últimos 10 anos?**
#
# <br>
#
# Dicas:
# 1. Para fazer essa questão você deve ter antes preenchido os valores nulos dos últimos 10 anos como na questão anterior. Isso estará feito se você já fez a questão anterior.
# 2. `sort_values()` pode ser útil aqui.

# %%
china_rank = df[['country','mean10years']].sort_values('mean10years',ascending=False)['country'].to_list().index('China') + 1

print( f"Posição da China no ranking dos maiores emissores em média nos últimos 10 anos: {china_rank :d}")
# Out:
# Posição da China no ranking dos maiores emissores em média nos últimos 10 anos: 41

# %% [markdown]
# ou

# %%
china_rank = len( df[ df['mean10years'] > df[ df.country ==  'China' ]['mean10years'].values[0] ] ) + 1

print( f"Posição da China no ranking dos maiores emissores em média nos últimos 10 anos: {china_rank :d}")
# Out:
# Posição da China no ranking dos maiores emissores em média nos últimos 10 anos: 41

# %% [markdown]
# # Q34. Emissões e Pareto (80/20)?
#
# **Qual o percentual de países responsáveis por 80% das emissões em 2018?**
#
# <br>
#
# Dica:
# 1. Você pode querer empregar o comando `cumsum()`.

# %%
df_2018 = df[['country','2018']].sort_values('2018',ascending=False)
df_2018['cumsum'] = df_2018['2018'].cumsum()
df_2018['cumpercent'] = df_2018['cumsum'] / df_2018['cumsum'].max()

perc_countries80co2 = len( df_2018[ df_2018['cumpercent'] <= 0.8 ] ) / len(df)

print( f"Percentual de países responsáveis por 80% das emissões: {perc_countries80co2 :.3f}")
# Out:
# Percentual de países responsáveis por 80% das emissões: 0.370

# %% [markdown]
# # Q35. Emissões na China
#
# **Qual o percentual de crescimento (ou descréscimo) das emissões médias da China entre as décadas de 1960 e última década na base?**
#
# <br>
#
# Dicas:
# 1. Você pode querer empregar a função `decade()` (construída em sala) para criar uma coluna de décadas e os valores médios de emissões para cada década.

# %%
def decade(year):
 return (year // 10) * 10

df = pd.read_csv(path + 'gapminder_co2_emissions_tonnes_per_person.csv') # ou exclua a coluna mean10years adicionada antes

china = df[ df.country == 'China' ].melt('country')
china = china.dropna()
china.variable = china.variable.astype('int')

china['decade'] = china.variable.apply(decade)

china.head()
# Out:
#     country  variable    value  decade
# 99    China      1899  0.00024    1890
# 102   China      1902  0.00023    1900
# 103   China      1903  0.00481    1900
# 104   China      1904  0.00509    1900
# 105   China      1905  0.00557    1900

# %%
china.groupby('decade').value.mean().head()
# Out:
# decade
# 1890    0.000240
# 1900    0.025087
# 1910    0.040590
# 1920    0.064800
# 1930    0.101580
# Name: value, dtype: float64

# %%
perc_decades = ( china.groupby('decade').value.mean().loc[2010] - china.groupby('decade').value.mean().loc[1960] ) / china.groupby('decade').value.mean().loc[1960]

print( f"Percentual de variação de emissões na China entre a década de 60 e a mais recente: {perc_decades :.3f}")
# Out:
# Percentual de variação de emissões na China entre a década de 60 e a mais recente: 8.640

# %% [markdown]
# # Q36. Países em atraso no controle de emissões
#
# **Que país passou a reportar mais tardiamente os dados sobre emissões? Informe o ano em que esse país passou a reportar suas emissões.**

# %%
df.melt(id_vars='country').dropna().groupby(['country']).variable.min()
# Out:
# country
# Afghanistan    1949
# Albania        1933
# Algeria        1900
# Andorra        1990
# Angola         1950
#                ...
# Venezuela      1904
# Vietnam        1892
# Yemen          1950
# Zambia         1959
# Zimbabwe       1903
# Name: variable, Length: 192, dtype: object

# %%
d2 = pd.DataFrame( df.melt(id_vars='country').dropna().groupby(['country']).variable.min() )
d2.variable = d2.variable.astype('int')
d2.nlargest(1,'variable')
# Out:
#              variable
# country
# Timor-Leste      2002

# %% [markdown]
# # **Case 4**: World Inequality
#
# Neste case analise a concentração de renda no Brasil.

# %% [markdown]
# <img src="https://wid.world/wp-content/uploads/2022/01/BannerHome-WIR-en.png" width=400>

# %%
wid = pd.read_csv(path + 'WID_Data_13092021-135730.csv')
wid.head()
# Out:
#   country                                    ind_description ind_code  year  \
# 0  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2000
# 1  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2001
# 2  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2002
# 3  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2003
# 4  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2004
#
#         value
# 0  16488.0559
# 1  16323.1697
# 2  16416.2538
# 3  16204.9913
# 4  16740.7222

# %% [markdown]
# Nesta última base há dois tipos de indicadores,

# %%
wid.ind_code.unique()
# Out:
# array(['pall', 'p90p100'], dtype=object)

# %% [markdown]
# * **`pall`** = corresponde ao PIB em USD
# * **`p90p100`** = corresponde ao percentual do PIB que se concentra em 90% da população mais pobre (por exemplo, se a distribuição fosse perfeitamente igualitária 90% da população corresponderia a 90% do PIB, e um percentual maior significa uma melhor distribuição de renda)

# %% [markdown]
# # Q41. A concentração de renda no Brasil aumentou ou diminui com base nos dados do período?
#
# **Compare os valores de `p90p100` do Brasil no ano mais antigo e no ano mais recente da base. A distribuição de renda no Brasil melhorou ao final do período?**

# %%
wid.drop(columns='ind_description',inplace=True) # somente para deixar mais limpo, esse atributo não será necessário

display( wid[ (wid.ind_code == 'p90p100') & (wid.year == wid.year.min()) ] )
display( wid[ (wid.ind_code == 'p90p100') & (wid.year == wid.year.max()) ] )
# Out:
#    country ind_code  year   value
# 20  Brazil  p90p100  2000  0.5654
#    country ind_code  year   value
# 39  Brazil  p90p100  2019  0.5856

# %% [markdown]
# # Q42. Qual a concentração média do PIB nas classes mais pobres no período?
#
# **Qual o valor médio do PIB atribuído a 90% da população mais pobre considerados todos os anos da base?**
#
# <br>
#
# Dica:
# 1. Entenda que o valor do PIB atribuído a 90% da população mais pobre é um percentual que é fornecido na base para cada ano.
# 2. `groupby()` pode ser um comando útil aqui, mas não é obrigatório.

# %%
wid_reshape = wid.groupby(['year','ind_code'])['value'].mean().unstack() # mean(), max(), min()... todos retornam o mesmo valor já que os valores são únicos
wid_reshape.head()
# Out:
# ind_code  p90p100        pall
# year
# 2000       0.5654  16488.0559
# 2001       0.5654  16323.1697
# 2002       0.5425  16416.2538
# 2003       0.5680  16204.9913
# 2004       0.5642  16740.7222

# %%
wid_reshape['p90p100_all'] = wid_reshape['p90p100'] * wid_reshape['pall']
wid_reshape.head()
# Out:
# ind_code  p90p100        pall  p90p100_all
# year
# 2000       0.5654  16488.0559  9322.346806
# 2001       0.5654  16323.1697  9229.120148
# 2002       0.5425  16416.2538  8905.817686
# 2003       0.5680  16204.9913  9204.435058
# 2004       0.5642  16740.7222  9445.115465

# %%
print( f"Valor médio do PIB no período atribuído a 90% dos mais pobres: {wid_reshape['p90p100_all'].mean() :.3f}")
# Out:
# Valor médio do PIB no período atribuído a 90% dos mais pobres: 10307.244

# %% [markdown]
# # **Case 5**: World Inequality $\times$ Gapminder
#
# Neste case analise as relações entre emissões de CO2, escolaridade e nível de concentração de renda no Brasil a partir das 3 bases abaixo.

# %% [markdown]
# <img src="https://wid.world/wp-content/uploads/2022/01/BannerHome-WIR-en.png" width=400>

# %%
school = pd.read_csv(path + 'gapminder_school_men_15_to_24_years.csv')
school_BR = school[ school.country == 'Brazil']
school_BR.head()
# Out:
#    country  1970  1971  1972  1973  1974  1975  1976  1977  1978  ...  2006  \
# 23  Brazil   3.4  3.47  3.55  3.64  3.72   3.8  3.89  3.97  4.06  ...  7.04
#
#     2007  2008  2009  2010  2011  2012  2013  2014  2015
# 23  7.17  7.29  7.42  7.55  7.68  7.81  7.94  8.08  8.21
#
# [1 rows x 47 columns]

# %%
co2 = pd.read_csv(path + 'gapminder_co2_emissions_tonnes_per_person.csv')
co2_BR = co2[ co2.country == 'Brazil']
co2_BR.head()
# Out:
#    country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  2009  \
# 23  Brazil   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.86
#
#     2010  2011  2012  2013  2014  2015  2016  2017  2018
# 23   2.1  2.18  2.31  2.46  2.59  2.42   2.2  2.23  2.18
#
# [1 rows x 220 columns]

# %%
wid = pd.read_csv(path + 'WID_Data_13092021-135730.csv')
wid.head()
# Out:
#   country                                    ind_description ind_code  year  \
# 0  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2000
# 1  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2001
# 2  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2002
# 3  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2003
# 4  Brazil  agdpro_pall_992_i_BR\nGross domestic product\n...     pall  2004
#
#         value
# 0  16488.0559
# 1  16323.1697
# 2  16416.2538
# 3  16204.9913
# 4  16740.7222

# %% [markdown]
# # Q51. Junção de dados
#
# Faça uma 'junção natural' (apenas instâncias associadas em ambas as relações)  dos dados de escolaridade e emissões de CO2 construindo um `dataframe` `school_co2_BR` como abaixo. **Qual o número de linhas e valor da soma de emissões obtido nesse novo `dataframe`?**
#
# <br>
#
# Dicas:
# 1. Pode ser útil empregar `melt()` e `merge()`.
# 2. Renomeie as colunas quando necessário.

# %%
school_BR_melt = school_BR.melt('country')
school_BR_melt.columns = ['country','year','school_years']
school_BR_melt.head()
# Out:
#   country  year  school_years
# 0  Brazil  1970          3.40
# 1  Brazil  1971          3.47
# 2  Brazil  1972          3.55
# 3  Brazil  1973          3.64
# 4  Brazil  1974          3.72

# %%
co2_BR_melt = co2_BR.melt('country')
co2_BR_melt.columns = ['country','year','co2']
co2_BR_melt.head()
# Out:
#   country  year  co2
# 0  Brazil  1800  NaN
# 1  Brazil  1801  NaN
# 2  Brazil  1802  NaN
# 3  Brazil  1803  NaN
# 4  Brazil  1804  NaN

# %%
school_co2_BR = school_BR_melt.merge(co2_BR_melt)
school_co2_BR.head()
# Out:
#   country  year  school_years    co2
# 0  Brazil  1970          3.40  0.984
# 1  Brazil  1971          3.47  1.050
# 2  Brazil  1972          3.55  1.140
# 3  Brazil  1973          3.64  1.290
# 4  Brazil  1974          3.72  1.370

# %%
print(f'Número de linhas: {len(school_co2_BR):d}')
print(f'Soma das emissões: {school_co2_BR.co2.sum():.2f}')
# Out:
# Número de linhas: 46
# Soma das emissões: 75.64

# %% [markdown]
# # Q52. Quanto o nível de escolaridade e de emissões caminham juntos no Brasil?
#
# No `dataframe` obtido na questão anterior, empregue o comando `corr()` para obter a correlação entre os valores de anos de escolaridade e emissões. **Qual a correlação entre os valores de anos de escolaridade e emissões ao longo do período?**.
#
# <br>
#
# Dicas:
# 1. `corr()` retorna uma matriz diagonal. A correlação entre duas variáveis é o valor de intersecção da linha e coluna correspondente às duas variáveis respectivamente.
# 2. É equivalente ao coeficiente de `pearson` e valores acima de $0.9$ correspondem a uma alta correlação entre as variáveis.

# %%
school_co2_BR[['school_years','co2']].corr()
# Out:
#               school_years       co2
# school_years      1.000000  0.916627
# co2               0.916627  1.000000

# %% [markdown]
# # Q53. Normalização de dados
#
# No `dataframe` da questão anterior normalize os dados de anos de escolaridade e emissões aplicando a normalização padrão (`standard`). **Qual a média e desvio padrão obtida dos valores normalizados?**.
#
# <br>
#
# Nota:
# 1. Normalização padrão (`standard`):
#
# $$ x_{std} = \frac{x - \bar{x}}{\sigma(x)}$$
#
# > onde $\bar{x}$ é o valor médio dos valores e $\sigma(x)$ o desvio padrão.
#
# Dica:
# 2. Você pode atribuir os valores diretamente ou criar uma função para isso, empregando ou não o `apply()`.

# %%
def normalize(column):
  return (column - column.mean()) / column.std()

school_co2_BR_std = school_co2_BR.copy()

school_co2_BR_std[['school_years','co2']] = school_co2_BR_std[['school_years','co2']].apply(normalize)
school_co2_BR_std.describe()
# Out:
#        school_years           co2
# count  4.600000e+01  4.600000e+01
# mean   1.448117e-17 -3.765104e-16
# std    1.000000e+00  1.000000e+00
# min   -1.520679e+00 -1.811541e+00
# 25%   -8.594850e-01 -6.636155e-01
# 50%   -8.028198e-02 -3.001744e-01
# 75%    8.117232e-01  5.364260e-01
# max    1.818266e+00  2.593640e+00

# %% [markdown]
# # Q54. Quanto o nível de escolaridade, emissões e concentração de renda (percentual do PIB dos 90% mais pobres) caminham juntos no Brasil?
#
# Faça agora uma nova 'junção natural' dos dados anteriores (apenas instâncias associadas em ambas as relações) com os dados de percentual do PIB (indicador `p90p100`) do `dataframe` `wid`. **Quais atributos, dentre escolaridade, emissões e percentual de concentração de renda, apresentam correlação maior no período? Normalize os dados (normalização padrão) e veja se os valores de correlação se mantêm.**
#
# <br>
#
# Dicas:
# 1. Certifique-se que os atributos de *match* do `merge()` são do mesmo tipo em cada `dataframe`. Para isso pode ser necessário fazer uma conversão de tipos como `df.coluna.astype('int64')`.
# 2. Você pode querer empregar a função de normalização da questão anterior.

# %%
school_co2_BR.year = school_co2_BR.year.astype('int64')

school_co2_p90p100_BR = school_co2_BR.merge(wid[ wid.ind_code == 'p90p100' ][['country','year','value']])
school_co2_p90p100_BR.rename(columns={'value':'p90p100'},inplace=True)
school_co2_p90p100_BR.head()
# Out:
#   country  year  school_years   co2  p90p100
# 0  Brazil  2000          6.32  1.86   0.5654
# 1  Brazil  2001          6.43  1.88   0.5654
# 2  Brazil  2002          6.55  1.83   0.5425
# 3  Brazil  2003          6.67  1.75   0.5680
# 4  Brazil  2004          6.79  1.81   0.5642

# %%
school_co2_p90p100_BR[['school_years','co2','p90p100']].corr()
# Out:
#               school_years       co2   p90p100
# school_years      1.000000  0.876336  0.693950
# co2               0.876336  1.000000  0.630229
# p90p100           0.693950  0.630229  1.000000

# %%
school_co2_p90p100_BR[['school_years','co2','p90p100']].apply(normalize).corr()
# Out:
#               school_years       co2   p90p100
# school_years      1.000000  0.876336  0.693950
# co2               0.876336  1.000000  0.630229
# p90p100           0.693950  0.630229  1.000000
